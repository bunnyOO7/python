# %%
def vendor():
    print("1 for cocacoal => 25Rs")
    print("2 for fanta  => 34Rs")
    print("3 for water bottle => 12Rs ")
    print("4 for burger => 10Rs")
    print("\n")
    n=int(input("enter your choice "))
    print("\n")
    ch,amt=user_ch(n)
    func(amt,ch)
   
    
def user_ch(n):
    m=n-1
    choice=["cock","fanta","water","burger"]
    amount=[25,34,12,10]
    choice=choice[m]
    amount=amount[m]
    return choice,amount
    
def func(amt,ch):
    print(f"selected item is {ch} ")
    print(f" price for that is  {amt}")
    print("\n")
    x=q=pop(a=0)
    pp=d={100:10,50:10,20:10,10:10,5:10,2:10,1:10}
    l=[q]
    z=[]
    if q>=amt:
        for i in d:
            if i<q:
                for j in range(d[i]):
                    q=q-i
                    if q<amt :
                        q=l[-1]
                        break
                    elif q>=amt:
                        d[i]=d[i]-1
                        l.append(q)
                        z.append(str(i))
                    else:
                        break

        for i in z:
            px=i
            amt=amt+int(px)
        if x==amt:
            print(f"your enter amt is {x}")
            for i in z:
                print(f"Returnig {i}")
            #print("your change is ","Rs,".join(z))
            print("\n")
            print(f"enjoy your {ch}"+"\U0001f600" )
        else:
            print("try again with another amt")
            pp=d
            print("\n\n")
            vendor()
    else:
        print("too short amt ")

        

def pop(a=0):
        global x
        print("press ENTER  after feed your Amount ")
        print("\n")
        while True:
            vv=input(" enter your Amount ")
            if vv=="":
                x=int(a)
                return x
            a=a+int(vv)
vendor()
